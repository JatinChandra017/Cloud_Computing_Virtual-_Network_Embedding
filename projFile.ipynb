# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/VCC_project/VNE_Input-main/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/VCC_project/VNE_Input-main'

# %%
# !unzip alib

# %%
# !pip install gurobipy
# !pip install Unidecode
# Out:
# Collecting gurobipy
#   Downloading gurobipy-9.5.1-cp37-cp37m-manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.9 MB/s
# Installing collected packages: gurobipy
# Successfully installed gurobipy-9.5.1
# Collecting Unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.1 MB/s
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.3.4

# %%
# # Graph Extraction

import os
import pickle
import sys
import graph
from vne import create_vne


class Extract:
    def get_graphs(self):
        os.chdir('/content/drive/MyDrive/Colab Notebooks/VCC_project/VNE_Input-main/')
        current = os.getcwd()
        print(current)
        current = os.path.join(
            os.path.dirname(current),
            "VNE_Input-main",
            "P3_ALIB_MASTER",
            "input",
            "senario_RedBestel.pickle",
        )
        with open(current, "rb") as f:
            data = pickle.load(f)
        para = graph.Parameters(10000, 500000, 10000, 500000, 0, 100, 0, 100, 1,
                                1) 
        substrate = graph.Graph(
            len(data.scenario_list[0].substrate.nodes),
            data.scenario_list[0].substrate.edges,
            para,
        )
        min_nodes=3
        max_nodes=5
        no_requests=4
        vne_list = create_vne(min_nodes, max_nodes, no_requests)
        return substrate, vne_list

# %%
x = Extract()
# substrate, vne_list = x.get_graphs(req_no = 15)    # USE THIS STATEMENT FOR AUTOMATION & comment line no 42
substrate, vne_list = x.get_graphs()
output = {"substrate": substrate, "vne_list": vne_list}
pickle_file = open("input.pickle", "wb")
pickle.dump(output, pickle_file)
# Out:
# /content/drive/MyDrive/Colab Notebooks/VCC_project/VNE_Input-main

# %%
# print("Substrate Network")
# # print("Nodes: ", substrate.nodes)
# print("Nodes & their Weights: ", substrate.node_weights)
# # print("Edges: ", substrate.edges)
# print("Edge & their Weights: ", substrate.edge_weights)
# print("Adj List: ", substrate.neighbours)
# Out:
# Substrate Network
# Nodes & their Weights:  {0: 385954, 1: 48177, 2: 431207, 3: 291507, 4: 189548, 5: 480689, 6: 281339, 7: 36646, 8: 28637, 9: 463396, 10: 461179, 11: 107175, 12: 203223, 13: 209224, 14: 113351, 15: 173109, 16: 468190, 17: 146703, 18: 71644, 19: 75959, 20: 369117, 21: 220603, 22: 347924, 23: 341798, 24: 428717, 25: 313065, 26: 434875, 27: 172329, 28: 290930, 29: 206516, 30: 32072, 31: 472031, 32: 366707, 33: 95013, 34: 401110, 35: 33540, 36: 42909, 37: 344870, 38: 360483, 39: 291745, 40: 144189, 41: 164431, 42: 137804, 43: 407723, 44: 483344, 45: 171403
', '7'}, 30: {'7', '45'}, 31: {'23', '24', '18'}, 32: {'19'}, 33: {'60', '19'}, 34: {'82', '79', '81'}, 35: {'40', '53'}, 36: {'13', '80'}, 37: {'38', '60'}, 38: {'37', '59', '19'}, 39: {'40'}, 40: {'35', '41', '39'}, 41: {'43', '42', '40'}, 42: {'41'}, 43: {'0', '41'}, 44: {'1', '0'}, 45: {'1', '30'}, 46: {'47', '69'}, 47: {'78', '46'}, 48: {'54', '20'}, 49: {'17', '72'}, 50: {'62', '70'}, 51: {'72', '67'}, 52: {'60', '5'}, 53: {'3', '35'}, 54: {'48', '6'}, 55: {'66', '13', '10', '11'}, 56: {'2', '83'}, 57: {'64', '58'}, 58: {'57', '14', '15'}, 59: {'38', '12', '19'}, 60: {'37', '33', '52', '11'}, 61: {'21', '69'}, 62: {'50', '63'}, 63: {'62', '16'}, 64: {'57'}, 65: {'4', '5'}, 66: {'12', '55'}, 67: {'51', '68'}, 68: {'70', '69', '67'}, 69: {'61', '68', '46'}, 70: {'50', '68'}, 71: {'1', '6'}, 72: {'51', '49'}, 73: {'74'}, 74: {'78', '73'}, 75: {'8', '13', '29'}, 76: {'77'}, 77: {'79', '78', '76'}, 78: {'74', '47', '17', '77'}, 79: {'34', '77'}, 80: {'36'}, 81: {'34'}, 82: {'34'}, 83: {'56'}}

# %%
# import graph

# Demo_Substrate Graph
nodes = 8
para = graph.Parameters(10, 50, 10, 30, 0, 100, 0, 100, 1, 1)
# edges = [('0', '1'), ('1', '0'), ('0', '4'), ('4', '0'), ('1', '2'), ('2', '1'),
        #  ('4', '1'), ('1', '4'), ('2', '3'), ('3', '2'), ('3', '4'), ('4', '3')]
edges = []
for i in range(nodes):
  for j in range(nodes):
    if i != j:
      edges.append((str(i), str(j)))
demo_substrate = graph.Graph(nodes, edges, para)

# %%
print("demo_substrate Network")
# print("Nodes: ", demo_substrate.nodes)
print("Nodes & their Weights: ", demo_substrate.node_weights)
# print("Edges: ", demo_substrate.edges)
print("Edge & their Weights: ", demo_substrate.edge_weights)
print("Adj List: ", demo_substrate.neighbours)
# Out:
# demo_substrate Network
# Nodes & their Weights:  {0: 12, 1: 24, 2: 15, 3: 22, 4: 16, 5: 19, 6: 18, 7: 26}
# Edge & their Weights:  {('0', '1'): 36, ('1', '0'): 36, ('0', '2'): 23, ('2', '0'): 23, ('0', '3'): 19, ('3', '0'): 19, ('0', '4'): 37, ('4', '0'): 37, ('0', '5'): 10, ('5', '0'): 10, ('0', '6'): 18, ('6', '0'): 18, ('0', '7'): 17, ('7', '0'): 17, ('1', '2'): 43, ('2', '1'): 43, ('1', '3'): 24, ('3', '1'): 24, ('1', '4'): 39, ('4', '1'): 39, ('1', '5'): 50, ('5', '1'): 50, ('1', '6'): 44, ('6', '1'): 44, ('1', '7'): 29, ('7', '1'): 29, ('2', '3'): 28, ('3', '2'): 28, ('2', '4'): 16, ('4', '2'): 16, ('2', '5'): 39, ('5', '2'): 39, ('2', '6'): 40, ('6', '2'): 40, ('2', '7'): 18, ('7', '2'): 18, ('3', '4'): 19, ('4', '3'): 19, ('3', '5'): 28, ('5', '3'): 28, ('3', '6'): 50, ('6', '3'): 50, ('3', '7'): 32, ('7', '3'): 32, ('4', '5'): 26, ('5', '4'): 26, ('4', '6'): 19, ('6', '4'): 19, ('4', '7'): 32, ('7', '4'): 32, ('5', '6'): 30, ('6', '5'): 30, ('5', '7'): 36, ('7', '5'): 36, ('6', '7'): 25, ('7', '6'): 25}
# Adj List:  {0: {'3', '7', '5', '4', '1', '2', '6'}, 1: {'3', '7', '5', '4', '0', '2', '6'}, 2: {'3', '7', '5', '4', '1', '0', '6'}, 3: {'7', '5', '4', '1', '0', '2', '6'}, 4: {'3', '7', '5', '1', '0', '2', '6'}, 5: {'3', '7', '4', '1', '0', '2', '6'}, 6: {'3', '7', '5', '4', '1', '0', '2'}, 7: {'3', '5', '4', '1', '0', '2', '6'}}

# %%
# importing networkx
import networkx as nx
# importing matplotlib.pyplot
import matplotlib.pyplot as plt

G_sub = nx.Graph()

for u,v in substrate.edges:
  G_sub.add_edge(u, v)

nx.draw(G_sub, with_labels = True)
plt.savefig("substrate.png")

# %%
G_demo_sub = nx.Graph()

for u,v in demo_substrate.edges:
  G_demo_sub.add_edge(u, v)

nx.draw(G_demo_sub, with_labels = True)
plt.savefig("demo_substrate.png")

# %%
for i in range(len(vne_list)):
  vne = vne_list[i]
  print("Request ", i+1)
  print("--------------------------------------------------------------")
  print("VNE Request")
  # print("Nodes: ", vne.nodes)
  print("Nodes & their Weights: ", vne.node_weights)
  # print("Edges: ", vne.edges)
  print("Edge & their Weights: ", vne.edge_weights)
  print("Adj List: ", vne.neighbours)
  print()
# Out:
# Request  1
# --------------------------------------------------------------
# VNE Request
# Nodes & their Weights:  {0: 6, 1: 12, 2: 15, 3: 13}
# Edge & their Weights:  {('0', '3'): 4, ('3', '0'): 4, ('2', '0'): 3, ('0', '2'): 3, ('1', '2'): 3, ('2', '1'): 3}
# Adj List:  {0: {'3', '2'}, 1: {'2'}, 2: {'1', '0'}, 3: {'0'}}
#
# Request  2
# --------------------------------------------------------------
# VNE Request
# Nodes & their Weights:  {0: 12, 1: 11, 2: 7, 3: 5, 4: 11}
# Edge & their Weights:  {('0', '3'): 1, ('3', '0'): 1, ('2', '3'): 10, ('3', '2'): 10, ('0', '4'): 6, ('4', '0'): 6, ('0', '1'): 4, ('1', '0'): 4}
# Adj List:  {0: {'3', '4', '1'}, 1: {'0'}, 2: {'3'}, 3: {'0', '2'}, 4: {'0'}}
#
# Request  3
# --------------------------------------------------------------
# VNE Request
# Nodes & their Weights:  {0: 14, 1: 10, 2: 10, 3: 15}
# Edge & their Weights:  {('2', '0'): 4, ('0', '2'): 4, ('1', '2'): 10, ('2', '1'): 10, ('2', '3'): 2, ('3', '2'): 2, ('3', '1'): 6, ('1', '3'): 6}
# Adj List:  {0: {'2'}, 1: {'3', '2'}, 2: {'3', '1', '0'}, 3: {'1', '2'}}
#
# Request  4
# --------------------------------------------------------------
# VNE Request
# Nodes & their Weights:  {0: 11, 1: 13, 2: 15, 3: 10}
# Edge & their Weights:  {('1', '2'): 5, ('2', '1'): 5, ('3', '1'): 9, ('1', '3'): 9, ('0', '1'): 4, ('1', '0'): 4}
# Adj List:  {0: {'1'}, 1: {'3', '0', '2'}, 2: {'1'}, 3: {'1'}}

# %%
for i in range(len(vne_list)):
  vne = vne_list[i]
  G_vne = nx.Graph()

  for u,v in vne.edges:
    G_vne.add_edge(u, v)
  plt.figure(i+1)
  nx.draw(G_vne, with_labels = True)
  plt.savefig("vne_"+str(i+1)+".png")
  # plt.clf()

# %%
import sys


trishul = [[0, 0]]*demo_substrate.nodes

def fun(s_nd, s_nd_cap, vne):
  cnt = 0
  temp_cap = s_nd_cap
  for v,c in vne.node_weights.items():
    if c < temp_cap:
      cnt += 1
      temp_cap -= c;
  return cnt

def updateTrishul(vne, curr_state_sg, v_nd_id, v_nd_cap):
  global trishul
  for s_nd, s_nd_cap in curr_state_sg.node_weights.items():
    numer = v_nd_cap
    temp = fun(s_nd, s_nd_cap, vne)
    if temp == s_nd_cap:
      tri = sys.maxsize
    else:
      denomer = s_nd_cap - temp
      tri = numer/denomer
    # print(s_nd)
    trishul[s_nd] = [tri, s_nd]

  trishul = sorted(trishul)

# %%
VNEmbed_nodes = [-1]*len(vne_list)
VNEmbed_edges = [-1]*len(vne_list)

# %%
for i in range(len(vne_list)):
  vne = vne_list[i]
  # print("Nodes: ", vne.nodes)
  mappingVtoS = {}
  mappingStoV = {}
  # print("Nodes: ", demo_substrate.nodes)
  curr_state_sg = demo_substrate


  # Node Mapping
  flag = False
  temp = sorted(vne.node_weights.items(), key = lambda kv:(kv[1]), reverse=True)
  for nd_id, nd_cap in temp:
    updateTrishul(vne, curr_state_sg, nd_id, nd_cap)
    for s_nd_from_tri in trishul:
      # print(trishul)
      # print(s_nd_from_tri[1], curr_state_sg.node_weights[s_nd_from_tri[1]])
      s_nd_cap = curr_state_sg.node_weights[s_nd_from_tri[1]]
      if nd_cap <= s_nd_cap and mappingStoV.get(s_nd_from_tri[1]) == None:
        mappingVtoS[str(nd_id)] = str(s_nd_from_tri[1])
        mappingStoV[str(s_nd_from_tri[1])] = str(nd_id)
        curr_state_sg.node_weights[s_nd_from_tri[1]] -= nd_cap
        break 
  
    if mappingVtoS.get(str(nd_id)) == None:
      flag = True
      print("Unable to embed all nodes for VNRequest_", i+1, " VNRequest Discarded")
      break
  if flag:
    continue

  if len(mappingVtoS) == vne.nodes:
    print("Node Mapping for VNRequest_", i+1, " is completed, Waiting for Link Mapping")
    # print(mappingVtoS)
    # print(mappingStoV)
  else:
    print("Unable to embed all nodes for VNRequest_", i+1, " VNRequest Discarded")
    continue

  print(mappingVtoS)
  # Link Mapping
  link_map_VtoS = {}
  for u,v in vne.edges:
    mapped_s_nd_u = mappingVtoS[u]
    mapped_s_nd_v = mappingVtoS[v]
    demand_uv = vne.edge_weights[(u, v)]
    all_path_uv = curr_state_sg.printAllPaths(mapped_s_nd_u, mapped_s_nd_v, demand_uv)
    all_path_uv.sort(key = len)
    if len(all_path_uv) == 0:
      print("Unable to embed all Links for VNRequest_", i+1, " VNRequest Discarded")
      break
    else:
      link_map_VtoS[(u, v)] = all_path_uv[0]
      for ix in range(len(all_path_uv[0])-1):
        ux = all_path_uv[0][ix]
        vx = all_path_uv[0][ix+1]
        vne.edge_weights[(ux, vx)] = curr_state_sg.edge_weights[(ux, vx)] - demand_uv
    
  if len(link_map_VtoS) == len(vne.edges):
    demo_substrate = curr_state_sg
    print("Link Mapping for VNRequest_", i+1, " is completed")
    VNEmbed_nodes[i] = mappingVtoS
    VNEmbed_edges[i] = link_map_VtoS
    # print(link_map_VtoS)
  else:
    print("Unable to embed all links for VNRequest_", i+1, " VNRequest Discarded")
  print("---------------------------------------------------------------------\n")
# Out:
# Node Mapping for VNRequest_ 1  is completed, Waiting for Link Mapping
# {'2': '7', '3': '1', '1': '3', '0': '5'}
# Link Mapping for VNRequest_ 1  is completed
# ---------------------------------------------------------------------
#
# Node Mapping for VNRequest_ 2  is completed, Waiting for Link Mapping
# {'0': '6', '1': '4', '4': '2', '2': '5', '3': '0'}
# Link Mapping for VNRequest_ 2  is completed
# ---------------------------------------------------------------------
#
# Unable to embed all nodes for VNRequest_ 3  VNRequest Discarded
# Unable to embed all nodes for VNRequest_ 4  VNRequest Discarded

# %%
for i in range(len(VNEmbed_nodes)):
  node_map = VNEmbed_nodes[i]
  edge_map = VNEmbed_edges[i]
  print("VNReques_", i+1)
  print(node_map)
  print(edge_map)
  print("----------------------------------------------\n")
# Out:
# VNReques_ 1
# {'2': '7', '3': '1', '1': '3', '0': '5'}
# {('0', '3'): ['5', '1'], ('2', '0'): ['7', '5'], ('3', '0'): ['1', '5'], ('1', '2'): ['3', '7'], ('0', '2'): ['5', '7'], ('2', '1'): ['7', '3']}
# ----------------------------------------------
#
# VNReques_ 2
# {'0': '6', '1': '4', '4': '2', '2': '5', '3': '0'}
# {('0', '3'): ['6', '0'], ('3', '0'): ['0', '6'], ('2', '3'): ['5', '0'], ('0', '4'): ['6', '2'], ('0', '1'): ['6', '4'], ('1', '0'): ['4', '6'], ('4', '0'): ['2', '6'], ('3', '2'): ['0', '5']}
# ----------------------------------------------
#
# VNReques_ 3
# -1
# -1
# ----------------------------------------------
#
# VNReques_ 4
# -1
# -1
# ----------------------------------------------
